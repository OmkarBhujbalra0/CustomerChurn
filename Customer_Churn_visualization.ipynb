# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
pd.set_option('display.max_rows',300)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['TotalCharges'].dtype
# Out:
# dtype('O')

# %%
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'],errors='coerce')

# %%
data['TotalCharges'].isnull().sum()
# Out:
# np.int64(11)

# %%
data['TotalCharges'] = data['TotalCharges'].fillna(data['TotalCharges'].median())

# %%
data['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
data['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
churn_rate = data['Churn'].value_counts(normalize=True)*100
churn_rate
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
sns.countplot(data=data,x='gender',hue='Churn')
plt.show()

# %%
sns.countplot(data=data,x='Contract',hue='Churn')
plt.show()

# %% [markdown]
# From the above graph, Month-to-Month Contract Customers are the one with highest Churn Count than both One year and Two Year Contract Customers.

# %%
sns.countplot(data=data,x='InternetService',hue='Churn')
plt.show()

# %% [markdown]
# No Internet has lowest Churn Count whereas Fiber Optic Users got highest Churn Count than DSL and No Internet.

# %%
sns.countplot(x='PaymentMethod',hue='Churn',data=data)
plt.show()

# %% [markdown]
# Credit Card Users got lowest Churn Count whereas Electronic Check Users got Highest Churn Count

# %%
sns.countplot(data=data,x='tenure',hue='Churn')
plt.show()

# %% [markdown]
# The Churn Count decreases as Tenure time increases

# %%
data['ChargesBin'] = pd.cut(data['MonthlyCharges'],bins= [0,30,60,90,120],labels=['0-30','31-60','61-90','91-120'])

# %%
sns.countplot(data=data,x='ChargesBin',hue='Churn')
plt.show()

# %% [markdown]
# Monthly Charges ranging from 61-90 has highest Churn count but 0-30 has lowest Churn Count

# %%
data['ChurnNum'] = data['Churn'].map({'Yes':1,'No':0})

# %%
data.groupby('Contract')['ChurnNum'].mean()
# Out:
# Contract
# Month-to-month    0.427097
# One year          0.112695
# Two year          0.028319
# Name: ChurnNum, dtype: float64

# %% [markdown]
# From the above observations, Customers under Month-to-Month Contract are at highest Churn Rate and Two Year Contract Customers are at lowest Churn Rate

# %%
data.groupby('InternetService')['ChurnNum'].mean()
# Out:
# InternetService
# DSL            0.189591
# Fiber optic    0.418928
# No             0.074050
# Name: ChurnNum, dtype: float64

# %% [markdown]
# Users having DSL as Service have highest Churn Rate and No Internet have lowest Churn Rate

# %%
data.groupby('ChargesBin')['ChurnNum'].mean()
# Out:
# /tmp/ipython-input-2598867628.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('ChargesBin')['ChurnNum'].mean()
# ChargesBin
# 0-30      0.098004
# 31-60     0.259289
# 61-90     0.339061
# 91-120    0.327775
# Name: ChurnNum, dtype: float64

# %% [markdown]
# Customers with Monthly Charges ranging from 61-90 have highest Churn Rate,91-120 have second highest and 0-30 have lowest Churn Rate

# %%
data.groupby('tenure')['ChurnNum'].mean()
# Out:
# tenure
# 0     0.000000
# 1     0.619902
# 2     0.516807
# 3     0.470000
# 4     0.471591
# 5     0.481203
# 6     0.363636
# 7     0.389313
# 8     0.341463
# 9     0.386555
# 10    0.387931
# 11    0.313131
# 12    0.324786
# 13    0.348624
# 14    0.315789
# 15    0.373737
# 16    0.350000
# 17    0.298851
# 18    0.247423
# 19    0.260274
# 20    0.253521
# 21    0.269841
# 22    0.300000
# 23    0.152941
# 24    0.244681
# 25    0.291139
# 26    0.189873
# 27    0.180556
# 28    0.210526
# 29    0.208333
# 30    0.222222
# 31    0.246154
# 32    0.275362
# 33    0.218750
# 34    0.184615
# 35    0.170455
# 36    0.200000
# 37    0.230769
# 38    0.220339
# 39    0.250000
# 40    0.203125
# 41    0.200000
# 42    0.215385
# 43    0.230769
# 44    0.117647
# 45    0.098361
# 46    0.162162
# 47    0.205882
# 48    0.140625
# 49    0.227273
# 50    0.147059
# 51    0.117647
# 52    0.100000
# 53    0.200000
# 54    0.191176
# 55    0.140625
# 56    0.125000
# 57    0.123077
# 58    0.164179
# 59    0.133333
# 60    0.078947
# 61    0.105263
# 62    0.071429
# 63    0.055556
# 64    0.050000
# 65    0.118421
# 66    0.146067
# 67    0.102041
# 68    0.090000
# 69    0.084211
# 70    0.092437
# 71    0.035294
# 72    0.016575
# Name: ChurnNum, dtype: float64

# %%
data['TenureBins'] = pd.cut(data['tenure'],bins=[0,24,48,72],labels=['0-24','25-48','49-72'])
data['TenureBins']
# Out:
# 0        0-24
# 1       25-48
# 2        0-24
# 3       25-48
# 4        0-24
#         ...
# 7038     0-24
# 7039    49-72
# 7040     0-24
# 7041     0-24
# 7042    49-72
# Name: TenureBins, Length: 7043, dtype: category
# Categories (3, object): ['0-24' < '25-48' < '49-72']

# %%
data.groupby('TenureBins')['ChurnNum'].mean()
# Out:
# /tmp/ipython-input-4164121857.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('TenureBins')['ChurnNum'].mean()
# TenureBins
# 0-24     0.416068
# 25-48    0.203890
# 49-72    0.095132
# Name: ChurnNum, dtype: float64

# %% [markdown]
# From the above observations, Churn Rate decreases with tenure range

# %%
data.groupby('PaymentMethod')['ChurnNum'].mean()
# Out:
# PaymentMethod
# Bank transfer (automatic)    0.167098
# Credit card (automatic)      0.152431
# Electronic check             0.452854
# Mailed check                 0.191067
# Name: ChurnNum, dtype: float64

# %% [markdown]
# Electronic Check got highest Churn Rate and Credit Card Users got lowest Churn Rate

# %%
risky_group = data.groupby(['PaymentMethod','InternetService','TenureBins','Contract'])['ChurnNum'].mean().reset_index()
risky_group
# Out:
# /tmp/ipython-input-3024364884.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   risky_group = data.groupby(['PaymentMethod','InternetService','TenureBins','Contract'])['ChurnNum'].mean().reset_index()
#                  PaymentMethod InternetService TenureBins        Contract  \
# 0    Bank transfer (automatic)             DSL       0-24  Month-to-month
# 1    Bank transfer (automatic)             DSL       0-24        One year
# 2    Bank transfer (automatic)             DSL       0-24        Two year
# 3    Bank transfer (automatic)             DSL      25-48  Month-to-month
# 4    Bank transfer (automatic)             DSL      25-48        One year
# 5    Bank transfer (automatic)             DSL      25-48        Two year
# 6    Bank transfer (automatic)             DSL      49-72  Month-to-month
# 7    Bank transfer (automatic)             DSL      49-72        One year
# 8    Bank transfer (automatic)             DSL      49-72        Two year
# 9    Bank transfer (automatic)     Fiber optic       0-24  Month-to-month
# 10   Bank transfer (automatic)     Fiber optic       0-24        One year
# 11   Bank transfer (automatic)     Fiber optic       0-24        Two year
# 12   Bank transfer (automatic)     Fiber optic      25-48  Month-to-month
# 13   Bank transfer (automatic)     Fiber optic      25-48        One year
# 14   Bank transfer (automatic)     Fiber optic      25-48        Two year
# 15   Bank transfer (automatic)     Fiber optic      49-72  Month-to-month
# 16   Bank transfer (automatic)     Fiber optic      49-72        One year
# 17   Bank transfer (automatic)     Fiber optic      49-72        Two year
# 18   Bank transfer (automatic)              No       0-24  Month-to-month
# 19   Bank transfer (automatic)              No       0-24        One year
# 20   Bank transfer (automatic)              No       0-24        Two year
# 21   Bank transfer (automatic)              No      25-48  Month-to-month
# 22   Bank transfer (automatic)              No      25-48        One year
# 23   Bank transfer (automatic)              No      25-48        Two year
# 24   Bank transfer (automatic)              No      49-72  Month-to-month
# 25   Bank transfer (automatic)              No      49-72        One year
# 26   Bank transfer (automatic)              No      49-72        Two year
# 27     Credit card (automatic)             DSL       0-24  Month-to-month
# 28     Credit card (automatic)             DSL       0-24        One year
# 29     Credit card (automatic)             DSL       0-24        Two year
# 30     Credit card (automatic)             DSL      25-48  Month-to-month
# 31     Credit card (automatic)             DSL      25-48        One year
# 32     Credit card (automatic)             DSL      25-48        Two year
# 33     Credit card (automatic)             DSL      49-72  Month-to-month
# 34     Credit card (automatic)             DSL      49-72        One year
# 35     Credit card (automatic)             DSL      49-72        Two year
# 36     Credit card (automatic)     Fiber optic       0-24  Month-to-month
# 37     Credit card (automatic)     Fiber optic       0-24        One year
# 38     Credit card (automatic)     Fiber optic       0-24        Two year
# 39     Credit card (automatic)     Fiber optic      25-48  Month-to-month
# 40     Credit card (automatic)     Fiber optic      25-48        One year
# 41     Credit card (automatic)     Fiber optic      25-48        Two year
# 42     Credit card (automatic)     Fiber optic      49-72  Month-to-month
# 43     Credit card (automatic)     Fiber optic      49-72        One year
# 44     Credit card (automatic)     Fiber optic      49-72        Two year
# 45     Credit card (automatic)              No       0-24  Month-to-month
# 46     Credit card (automatic)              No       0-24        One year
# 47     Credit card (automatic)              No       0-24        Two year
# 48     Credit card (automatic)              No      25-48  Month-to-month
# 49     Credit card (automatic)              No      25-48        One year
# 50     Credit card (automatic)              No      25-48        Two year
# 51     Credit card (automatic)              No      49-72  Month-to-month
# 52     Credit card (automatic)              No      49-72        One year
# 53     Credit card (automatic)              No      49-72        Two year
# 54            Electronic check             DSL       0-24  Month-to-month
# 55            Electronic check             DSL       0-24        One year
# 56            Electronic check             DSL       0-24        Two year
# 57            Electronic check             DSL      25-48  Month-to-month
# 58            Electronic check             DSL      25-48        One year
# 59            Electronic check             DSL      25-48        Two year
# 60            Electronic check             DSL      49-72  Month-to-month
# 61            Electronic check             DSL      49-72        One year
# 62            Electronic check             DSL      49-72        Two year
# 63            Electronic check     Fiber optic       0-24  Month-to-month
# 64            Electronic check     Fiber optic       0-24        One year
# 65            Electronic check     Fiber optic       0-24        Two year
# 66            Electronic check     Fiber optic      25-48  Month-to-month
# 67            Electronic check     Fiber optic      25-48        One year
# 68            Electronic check     Fiber optic      25-48        Two year
# 69            Electronic check     Fiber optic      49-72  Month-to-month
# 70            Electronic check     Fiber optic      49-72        One year
# 71            Electronic check     Fiber optic      49-72        Two year
# 72            Electronic check              No       0-24  Month-to-month
# 73            Electronic check              No       0-24        One year
# 74            Electronic check              No       0-24        Two year
# 75            Electronic check              No      25-48  Month-to-month
# 76            Electronic check              No      25-48        One year
# 77            Electronic check              No      25-48        Two year
# 78            Electronic check              No      49-72  Month-to-month
# 79            Electronic check              No      49-72        One year
# 80            Electronic check              No      49-72        Two year
# 81                Mailed check             DSL       0-24  Month-to-month
# 82                Mailed check             DSL       0-24        One year
# 83                Mailed check             DSL       0-24        Two year
# 84                Mailed check             DSL      25-48  Month-to-month
# 85                Mailed check             DSL      25-48        One year
# 86                Mailed check             DSL      25-48        Two year
# 87                Mailed check             DSL      49-72  Month-to-month
# 88                Mailed check             DSL      49-72        One year
# 89                Mailed check             DSL      49-72        Two year
# 90                Mailed check     Fiber optic       0-24  Month-to-month
# 91                Mailed check     Fiber optic       0-24        One year
# 92                Mailed check     Fiber optic       0-24        Two year
# 93                Mailed check     Fiber optic      25-48  Month-to-month
# 94                Mailed check     Fiber optic      25-48        One year
# 95                Mailed check     Fiber optic      25-48        Two year
# 96                Mailed check     Fiber optic      49-72  Month-to-month
# 97                Mailed check     Fiber optic      49-72        One year
# 98                Mailed check     Fiber optic      49-72        Two year
# 99                Mailed check              No       0-24  Month-to-month
# 100               Mailed check              No       0-24        One year
# 101               Mailed check              No       0-24        Two year
# 102               Mailed check              No      25-48  Month-to-month
# 103               Mailed check              No      25-48        One year
# 104               Mailed check              No      25-48        Two year
# 105               Mailed check              No      49-72  Month-to-month
# 106               Mailed check              No      49-72        One year
# 107               Mailed check              No      49-72        Two year
#
#      ChurnNum
# 0    0.237288
# 1    0.173913
# 2    0.000000
# 3    0.157895
# 4    0.056604
# 5    0.000000
# 6    0.090909
# 7    0.057971
# 8    0.015075
# 9    0.594937
# 10   0.333333
# 11        NaN
# 12   0.411765
# 13   0.080000
# 14   0.000000
# 15   0.194030
# 16   0.168317
# 17   0.099338
# 18   0.230769
# 19   0.071429
# 20   0.000000
# 21   0.076923
# 22   0.027027
# 23   0.000000
# 24        NaN
# 25   0.041667
# 26   0.007752
# 27   0.313559
# 28   0.192308
# 29   0.000000
# 30   0.220000
# 31   0.103896
# 32   0.032258
# 33   0.117647
# 34   0.057971
# 35   0.020305
# 36   0.540146
# 37   0.000000
# 38        NaN
# 39   0.323529
# 40   0.171429
# 41   0.000000
# 42   0.277778
# 43   0.160377
# 44   0.041379
# 45   0.105263
# 46   0.037037
# 47   0.000000
# 48   0.000000
# 49   0.000000
# 50   0.025000
# 51   0.000000
# 52   0.000000
# 53   0.007874
# 54   0.468665
# 55   0.153846
# 56   0.000000
# 57   0.181818
# 58   0.043478
# 59   0.000000
# 60   0.200000
# 61   0.113636
# 62   0.081633
# 63   0.676072
# 64   0.250000
# 65   0.000000
# 66   0.489510
# 67   0.288136
# 68   0.200000
# 69   0.370370
# 70   0.248062
# 71   0.086420
# 72   0.232143
# 73   0.000000
# 74   0.000000
# 75   0.000000
# 76   0.083333
# 77   0.000000
# 78        NaN
# 79   0.090909
# 80   0.000000
# 81   0.347962
# 82   0.108696
# 83   0.000000
# 84   0.046512
# 85   0.138462
# 86   0.000000
# 87   0.000000
# 88   0.000000
# 89   0.000000
# 90   0.568750
# 91   0.285714
# 92        NaN
# 93   0.354839
# 94   0.400000
# 95   0.200000
# 96   0.000000
# 97   0.052632
# 98   0.000000
# 99   0.214521
# 100  0.019608
# 101  0.000000
# 102  0.047619
# 103  0.000000
# 104  0.013158
# 105  1.000000
# 106  0.000000
# 107  0.010000

# %%
risky_group.sort_values(by='ChurnNum',ascending=False).head(5)
# Out:
#                  PaymentMethod InternetService TenureBins        Contract  \
# 105               Mailed check              No      49-72  Month-to-month
# 63            Electronic check     Fiber optic       0-24  Month-to-month
# 9    Bank transfer (automatic)     Fiber optic       0-24  Month-to-month
# 90                Mailed check     Fiber optic       0-24  Month-to-month
# 36     Credit card (automatic)     Fiber optic       0-24  Month-to-month
#
#      ChurnNum
# 105  1.000000
# 63   0.676072
# 9    0.594937
# 90   0.568750
# 36   0.540146

# %%
risky_group.sort_values(by='ChurnNum',ascending=False).tail(5)
# Out:
#                 PaymentMethod InternetService TenureBins        Contract  \
# 11  Bank transfer (automatic)     Fiber optic       0-24        Two year
# 24  Bank transfer (automatic)              No      49-72  Month-to-month
# 38    Credit card (automatic)     Fiber optic       0-24        Two year
# 78           Electronic check              No      49-72  Month-to-month
# 92               Mailed check     Fiber optic       0-24        Two year
#
#     ChurnNum
# 11       NaN
# 24       NaN
# 38       NaN
# 78       NaN
# 92       NaN

# %%
risky_group.dropna(inplace=True)
risky_group.shape
# Out:
# (103, 5)

# %%
risky_group.sort_values(by='ChurnNum',ascending=False).tail(5)
# Out:
#     PaymentMethod InternetService TenureBins        Contract  ChurnNum
# 96   Mailed check     Fiber optic      49-72  Month-to-month       0.0
# 98   Mailed check     Fiber optic      49-72        Two year       0.0
# 101  Mailed check              No       0-24        Two year       0.0
# 103  Mailed check              No      25-48        One year       0.0
# 106  Mailed check              No      49-72        One year       0.0

# %%
count = data.groupby(['PaymentMethod','InternetService','TenureBins','Contract']).size().reset_index(name='Count')
count
# Out:
# /tmp/ipython-input-2784848500.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   count = data.groupby(['PaymentMethod','InternetService','TenureBins','Contract']).size().reset_index(name='Count')
#                  PaymentMethod InternetService TenureBins        Contract  \
# 0    Bank transfer (automatic)             DSL       0-24  Month-to-month
# 1    Bank transfer (automatic)             DSL       0-24        One year
# 2    Bank transfer (automatic)             DSL       0-24        Two year
# 3    Bank transfer (automatic)             DSL      25-48  Month-to-month
# 4    Bank transfer (automatic)             DSL      25-48        One year
# 5    Bank transfer (automatic)             DSL      25-48        Two year
# 6    Bank transfer (automatic)             DSL      49-72  Month-to-month
# 7    Bank transfer (automatic)             DSL      49-72        One year
# 8    Bank transfer (automatic)             DSL      49-72        Two year
# 9    Bank transfer (automatic)     Fiber optic       0-24  Month-to-month
# 10   Bank transfer (automatic)     Fiber optic       0-24        One year
# 11   Bank transfer (automatic)     Fiber optic       0-24        Two year
# 12   Bank transfer (automatic)     Fiber optic      25-48  Month-to-month
# 13   Bank transfer (automatic)     Fiber optic      25-48        One year
# 14   Bank transfer (automatic)     Fiber optic      25-48        Two year
# 15   Bank transfer (automatic)     Fiber optic      49-72  Month-to-month
# 16   Bank transfer (automatic)     Fiber optic      49-72        One year
# 17   Bank transfer (automatic)     Fiber optic      49-72        Two year
# 18   Bank transfer (automatic)              No       0-24  Month-to-month
# 19   Bank transfer (automatic)              No       0-24        One year
# 20   Bank transfer (automatic)              No       0-24        Two year
# 21   Bank transfer (automatic)              No      25-48  Month-to-month
# 22   Bank transfer (automatic)              No      25-48        One year
# 23   Bank transfer (automatic)              No      25-48        Two year
# 24   Bank transfer (automatic)              No      49-72  Month-to-month
# 25   Bank transfer (automatic)              No      49-72        One year
# 26   Bank transfer (automatic)              No      49-72        Two year
# 27     Credit card (automatic)             DSL       0-24  Month-to-month
# 28     Credit card (automatic)             DSL       0-24        One year
# 29     Credit card (automatic)             DSL       0-24        Two year
# 30     Credit card (automatic)             DSL      25-48  Month-to-month
# 31     Credit card (automatic)             DSL      25-48        One year
# 32     Credit card (automatic)             DSL      25-48        Two year
# 33     Credit card (automatic)             DSL      49-72  Month-to-month
# 34     Credit card (automatic)             DSL      49-72        One year
# 35     Credit card (automatic)             DSL      49-72        Two year
# 36     Credit card (automatic)     Fiber optic       0-24  Month-to-month
# 37     Credit card (automatic)     Fiber optic       0-24        One year
# 38     Credit card (automatic)     Fiber optic       0-24        Two year
# 39     Credit card (automatic)     Fiber optic      25-48  Month-to-month
# 40     Credit card (automatic)     Fiber optic      25-48        One year
# 41     Credit card (automatic)     Fiber optic      25-48        Two year
# 42     Credit card (automatic)     Fiber optic      49-72  Month-to-month
# 43     Credit card (automatic)     Fiber optic      49-72        One year
# 44     Credit card (automatic)     Fiber optic      49-72        Two year
# 45     Credit card (automatic)              No       0-24  Month-to-month
# 46     Credit card (automatic)              No       0-24        One year
# 47     Credit card (automatic)              No       0-24        Two year
# 48     Credit card (automatic)              No      25-48  Month-to-month
# 49     Credit card (automatic)              No      25-48        One year
# 50     Credit card (automatic)              No      25-48        Two year
# 51     Credit card (automatic)              No      49-72  Month-to-month
# 52     Credit card (automatic)              No      49-72        One year
# 53     Credit card (automatic)              No      49-72        Two year
# 54            Electronic check             DSL       0-24  Month-to-month
# 55            Electronic check             DSL       0-24        One year
# 56            Electronic check             DSL       0-24        Two year
# 57            Electronic check             DSL      25-48  Month-to-month
# 58            Electronic check             DSL      25-48        One year
# 59            Electronic check             DSL      25-48        Two year
# 60            Electronic check             DSL      49-72  Month-to-month
# 61            Electronic check             DSL      49-72        One year
# 62            Electronic check             DSL      49-72        Two year
# 63            Electronic check     Fiber optic       0-24  Month-to-month
# 64            Electronic check     Fiber optic       0-24        One year
# 65            Electronic check     Fiber optic       0-24        Two year
# 66            Electronic check     Fiber optic      25-48  Month-to-month
# 67            Electronic check     Fiber optic      25-48        One year
# 68            Electronic check     Fiber optic      25-48        Two year
# 69            Electronic check     Fiber optic      49-72  Month-to-month
# 70            Electronic check     Fiber optic      49-72        One year
# 71            Electronic check     Fiber optic      49-72        Two year
# 72            Electronic check              No       0-24  Month-to-month
# 73            Electronic check              No       0-24        One year
# 74            Electronic check              No       0-24        Two year
# 75            Electronic check              No      25-48  Month-to-month
# 76            Electronic check              No      25-48        One year
# 77            Electronic check              No      25-48        Two year
# 78            Electronic check              No      49-72  Month-to-month
# 79            Electronic check              No      49-72        One year
# 80            Electronic check              No      49-72        Two year
# 81                Mailed check             DSL       0-24  Month-to-month
# 82                Mailed check             DSL       0-24        One year
# 83                Mailed check             DSL       0-24        Two year
# 84                Mailed check             DSL      25-48  Month-to-month
# 85                Mailed check             DSL      25-48        One year
# 86                Mailed check             DSL      25-48        Two year
# 87                Mailed check             DSL      49-72  Month-to-month
# 88                Mailed check             DSL      49-72        One year
# 89                Mailed check             DSL      49-72        Two year
# 90                Mailed check     Fiber optic       0-24  Month-to-month
# 91                Mailed check     Fiber optic       0-24        One year
# 92                Mailed check     Fiber optic       0-24        Two year
# 93                Mailed check     Fiber optic      25-48  Month-to-month
# 94                Mailed check     Fiber optic      25-48        One year
# 95                Mailed check     Fiber optic      25-48        Two year
# 96                Mailed check     Fiber optic      49-72  Month-to-month
# 97                Mailed check     Fiber optic      49-72        One year
# 98                Mailed check     Fiber optic      49-72        Two year
# 99                Mailed check              No       0-24  Month-to-month
# 100               Mailed check              No       0-24        One year
# 101               Mailed check              No       0-24        Two year
# 102               Mailed check              No      25-48  Month-to-month
# 103               Mailed check              No      25-48        One year
# 104               Mailed check              No      25-48        Two year
# 105               Mailed check              No      49-72  Month-to-month
# 106               Mailed check              No      49-72        One year
# 107               Mailed check              No      49-72        Two year
#
#      Count
# 0      118
# 1       23
# 2        5
# 3       57
# 4       53
# 5       18
# 6       22
# 7       69
# 8      199
# 9      158
# 10       6
# 11       0
# 12     102
# 13      50
# 14      11
# 15      67
# 16     101
# 17     151
# 18      52
# 19      28
# 20      14
# 21      13
# 22      37
# 23      35
# 24       0
# 25      24
# 26     129
# 27     118
# 28      26
# 29       8
# 30      50
# 31      77
# 32      31
# 33      17
# 34      69
# 35     197
# 36     137
# 37       9
# 38       0
# 39     102
# 40      35
# 41       9
# 42      54
# 43     106
# 44     145
# 45      57
# 46      27
# 47      23
# 48       7
# 49      28
# 50      40
# 51       1
# 52      21
# 53     127
# 54     367
# 55      26
# 56       1
# 57      77
# 58      46
# 59       8
# 60      30
# 61      44
# 62      49
# 63     886
# 64       8
# 65       1
# 66     286
# 67      59
# 68      10
# 69     135
# 70     129
# 71      81
# 72      56
# 73      12
# 74       1
# 75      13
# 76      12
# 77       9
# 78       0
# 79      11
# 80       8
# 81     319
# 82      46
# 83      24
# 84      43
# 85      65
# 86      22
# 87       5
# 88      26
# 89      61
# 90     160
# 91       7
# 92       0
# 93      31
# 94      10
# 95       5
# 96      10
# 97      19
# 98      16
# 99     303
# 100    102
# 101     71
# 102     21
# 103     46
# 104     76
# 105      1
# 106     15
# 107    100

# %%
risky_group = risky_group.merge(count,on=['PaymentMethod','InternetService','TenureBins','Contract'])
risky_group
# Out:
#                  PaymentMethod InternetService TenureBins        Contract  \
# 0    Bank transfer (automatic)             DSL       0-24  Month-to-month
# 1    Bank transfer (automatic)             DSL       0-24        One year
# 2    Bank transfer (automatic)             DSL       0-24        Two year
# 3    Bank transfer (automatic)             DSL      25-48  Month-to-month
# 4    Bank transfer (automatic)             DSL      25-48        One year
# 5    Bank transfer (automatic)             DSL      25-48        Two year
# 6    Bank transfer (automatic)             DSL      49-72  Month-to-month
# 7    Bank transfer (automatic)             DSL      49-72        One year
# 8    Bank transfer (automatic)             DSL      49-72        Two year
# 9    Bank transfer (automatic)     Fiber optic       0-24  Month-to-month
# 10   Bank transfer (automatic)     Fiber optic       0-24        One year
# 11   Bank transfer (automatic)     Fiber optic      25-48  Month-to-month
# 12   Bank transfer (automatic)     Fiber optic      25-48        One year
# 13   Bank transfer (automatic)     Fiber optic      25-48        Two year
# 14   Bank transfer (automatic)     Fiber optic      49-72  Month-to-month
# 15   Bank transfer (automatic)     Fiber optic      49-72        One year
# 16   Bank transfer (automatic)     Fiber optic      49-72        Two year
# 17   Bank transfer (automatic)              No       0-24  Month-to-month
# 18   Bank transfer (automatic)              No       0-24        One year
# 19   Bank transfer (automatic)              No       0-24        Two year
# 20   Bank transfer (automatic)              No      25-48  Month-to-month
# 21   Bank transfer (automatic)              No      25-48        One year
# 22   Bank transfer (automatic)              No      25-48        Two year
# 23   Bank transfer (automatic)              No      49-72        One year
# 24   Bank transfer (automatic)              No      49-72        Two year
# 25     Credit card (automatic)             DSL       0-24  Month-to-month
# 26     Credit card (automatic)             DSL       0-24        One year
# 27     Credit card (automatic)             DSL       0-24        Two year
# 28     Credit card (automatic)             DSL      25-48  Month-to-month
# 29     Credit card (automatic)             DSL      25-48        One year
# 30     Credit card (automatic)             DSL      25-48        Two year
# 31     Credit card (automatic)             DSL      49-72  Month-to-month
# 32     Credit card (automatic)             DSL      49-72        One year
# 33     Credit card (automatic)             DSL      49-72        Two year
# 34     Credit card (automatic)     Fiber optic       0-24  Month-to-month
# 35     Credit card (automatic)     Fiber optic       0-24        One year
# 36     Credit card (automatic)     Fiber optic      25-48  Month-to-month
# 37     Credit card (automatic)     Fiber optic      25-48        One year
# 38     Credit card (automatic)     Fiber optic      25-48        Two year
# 39     Credit card (automatic)     Fiber optic      49-72  Month-to-month
# 40     Credit card (automatic)     Fiber optic      49-72        One year
# 41     Credit card (automatic)     Fiber optic      49-72        Two year
# 42     Credit card (automatic)              No       0-24  Month-to-month
# 43     Credit card (automatic)              No       0-24        One year
# 44     Credit card (automatic)              No       0-24        Two year
# 45     Credit card (automatic)              No      25-48  Month-to-month
# 46     Credit card (automatic)              No      25-48        One year
# 47     Credit card (automatic)              No      25-48        Two year
# 48     Credit card (automatic)              No      49-72  Month-to-month
# 49     Credit card (automatic)              No      49-72        One year
# 50     Credit card (automatic)              No      49-72        Two year
# 51            Electronic check             DSL       0-24  Month-to-month
# 52            Electronic check             DSL       0-24        One year
# 53            Electronic check             DSL       0-24        Two year
# 54            Electronic check             DSL      25-48  Month-to-month
# 55            Electronic check             DSL      25-48        One year
# 56            Electronic check             DSL      25-48        Two year
# 57            Electronic check             DSL      49-72  Month-to-month
# 58            Electronic check             DSL      49-72        One year
# 59            Electronic check             DSL      49-72        Two year
# 60            Electronic check     Fiber optic       0-24  Month-to-month
# 61            Electronic check     Fiber optic       0-24        One year
# 62            Electronic check     Fiber optic       0-24        Two year
# 63            Electronic check     Fiber optic      25-48  Month-to-month
# 64            Electronic check     Fiber optic      25-48        One year
# 65            Electronic check     Fiber optic      25-48        Two year
# 66            Electronic check     Fiber optic      49-72  Month-to-month
# 67            Electronic check     Fiber optic      49-72        One year
# 68            Electronic check     Fiber optic      49-72        Two year
# 69            Electronic check              No       0-24  Month-to-month
# 70            Electronic check              No       0-24        One year
# 71            Electronic check              No       0-24        Two year
# 72            Electronic check              No      25-48  Month-to-month
# 73            Electronic check              No      25-48        One year
# 74            Electronic check              No      25-48        Two year
# 75            Electronic check              No      49-72        One year
# 76            Electronic check              No      49-72        Two year
# 77                Mailed check             DSL       0-24  Month-to-month
# 78                Mailed check             DSL       0-24        One year
# 79                Mailed check             DSL       0-24        Two year
# 80                Mailed check             DSL      25-48  Month-to-month
# 81                Mailed check             DSL      25-48        One year
# 82                Mailed check             DSL      25-48        Two year
# 83                Mailed check             DSL      49-72  Month-to-month
# 84                Mailed check             DSL      49-72        One year
# 85                Mailed check             DSL      49-72        Two year
# 86                Mailed check     Fiber optic       0-24  Month-to-month
# 87                Mailed check     Fiber optic       0-24        One year
# 88                Mailed check     Fiber optic      25-48  Month-to-month
# 89                Mailed check     Fiber optic      25-48        One year
# 90                Mailed check     Fiber optic      25-48        Two year
# 91                Mailed check     Fiber optic      49-72  Month-to-month
# 92                Mailed check     Fiber optic      49-72        One year
# 93                Mailed check     Fiber optic      49-72        Two year
# 94                Mailed check              No       0-24  Month-to-month
# 95                Mailed check              No       0-24        One year
# 96                Mailed check              No       0-24        Two year
# 97                Mailed check              No      25-48  Month-to-month
# 98                Mailed check              No      25-48        One year
# 99                Mailed check              No      25-48        Two year
# 100               Mailed check              No      49-72  Month-to-month
# 101               Mailed check              No      49-72        One year
# 102               Mailed check              No      49-72        Two year
#
#      ChurnNum  Count
# 0    0.237288    118
# 1    0.173913     23
# 2    0.000000      5
# 3    0.157895     57
# 4    0.056604     53
# 5    0.000000     18
# 6    0.090909     22
# 7    0.057971     69
# 8    0.015075    199
# 9    0.594937    158
# 10   0.333333      6
# 11   0.411765    102
# 12   0.080000     50
# 13   0.000000     11
# 14   0.194030     67
# 15   0.168317    101
# 16   0.099338    151
# 17   0.230769     52
# 18   0.071429     28
# 19   0.000000     14
# 20   0.076923     13
# 21   0.027027     37
# 22   0.000000     35
# 23   0.041667     24
# 24   0.007752    129
# 25   0.313559    118
# 26   0.192308     26
# 27   0.000000      8
# 28   0.220000     50
# 29   0.103896     77
# 30   0.032258     31
# 31   0.117647     17
# 32   0.057971     69
# 33   0.020305    197
# 34   0.540146    137
# 35   0.000000      9
# 36   0.323529    102
# 37   0.171429     35
# 38   0.000000      9
# 39   0.277778     54
# 40   0.160377    106
# 41   0.041379    145
# 42   0.105263     57
# 43   0.037037     27
# 44   0.000000     23
# 45   0.000000      7
# 46   0.000000     28
# 47   0.025000     40
# 48   0.000000      1
# 49   0.000000     21
# 50   0.007874    127
# 51   0.468665    367
# 52   0.153846     26
# 53   0.000000      1
# 54   0.181818     77
# 55   0.043478     46
# 56   0.000000      8
# 57   0.200000     30
# 58   0.113636     44
# 59   0.081633     49
# 60   0.676072    886
# 61   0.250000      8
# 62   0.000000      1
# 63   0.489510    286
# 64   0.288136     59
# 65   0.200000     10
# 66   0.370370    135
# 67   0.248062    129
# 68   0.086420     81
# 69   0.232143     56
# 70   0.000000     12
# 71   0.000000      1
# 72   0.000000     13
# 73   0.083333     12
# 74   0.000000      9
# 75   0.090909     11
# 76   0.000000      8
# 77   0.347962    319
# 78   0.108696     46
# 79   0.000000     24
# 80   0.046512     43
# 81   0.138462     65
# 82   0.000000     22
# 83   0.000000      5
# 84   0.000000     26
# 85   0.000000     61
# 86   0.568750    160
# 87   0.285714      7
# 88   0.354839     31
# 89   0.400000     10
# 90   0.200000      5
# 91   0.000000     10
# 92   0.052632     19
# 93   0.000000     16
# 94   0.214521    303
# 95   0.019608    102
# 96   0.000000     71
# 97   0.047619     21
# 98   0.000000     46
# 99   0.013158     76
# 100  1.000000      1
# 101  0.000000     15
# 102  0.010000    100

# %%
risky_group = risky_group[risky_group['Count'] > 30]
risky_group
# Out:
#                  PaymentMethod InternetService TenureBins        Contract  \
# 0    Bank transfer (automatic)             DSL       0-24  Month-to-month
# 3    Bank transfer (automatic)             DSL      25-48  Month-to-month
# 4    Bank transfer (automatic)             DSL      25-48        One year
# 7    Bank transfer (automatic)             DSL      49-72        One year
# 8    Bank transfer (automatic)             DSL      49-72        Two year
# 9    Bank transfer (automatic)     Fiber optic       0-24  Month-to-month
# 11   Bank transfer (automatic)     Fiber optic      25-48  Month-to-month
# 12   Bank transfer (automatic)     Fiber optic      25-48        One year
# 14   Bank transfer (automatic)     Fiber optic      49-72  Month-to-month
# 15   Bank transfer (automatic)     Fiber optic      49-72        One year
# 16   Bank transfer (automatic)     Fiber optic      49-72        Two year
# 17   Bank transfer (automatic)              No       0-24  Month-to-month
# 21   Bank transfer (automatic)              No      25-48        One year
# 22   Bank transfer (automatic)              No      25-48        Two year
# 24   Bank transfer (automatic)              No      49-72        Two year
# 25     Credit card (automatic)             DSL       0-24  Month-to-month
# 28     Credit card (automatic)             DSL      25-48  Month-to-month
# 29     Credit card (automatic)             DSL      25-48        One year
# 30     Credit card (automatic)             DSL      25-48        Two year
# 32     Credit card (automatic)             DSL      49-72        One year
# 33     Credit card (automatic)             DSL      49-72        Two year
# 34     Credit card (automatic)     Fiber optic       0-24  Month-to-month
# 36     Credit card (automatic)     Fiber optic      25-48  Month-to-month
# 37     Credit card (automatic)     Fiber optic      25-48        One year
# 39     Credit card (automatic)     Fiber optic      49-72  Month-to-month
# 40     Credit card (automatic)     Fiber optic      49-72        One year
# 41     Credit card (automatic)     Fiber optic      49-72        Two year
# 42     Credit card (automatic)              No       0-24  Month-to-month
# 47     Credit card (automatic)              No      25-48        Two year
# 50     Credit card (automatic)              No      49-72        Two year
# 51            Electronic check             DSL       0-24  Month-to-month
# 54            Electronic check             DSL      25-48  Month-to-month
# 55            Electronic check             DSL      25-48        One year
# 58            Electronic check             DSL      49-72        One year
# 59            Electronic check             DSL      49-72        Two year
# 60            Electronic check     Fiber optic       0-24  Month-to-month
# 63            Electronic check     Fiber optic      25-48  Month-to-month
# 64            Electronic check     Fiber optic      25-48        One year
# 66            Electronic check     Fiber optic      49-72  Month-to-month
# 67            Electronic check     Fiber optic      49-72        One year
# 68            Electronic check     Fiber optic      49-72        Two year
# 69            Electronic check              No       0-24  Month-to-month
# 77                Mailed check             DSL       0-24  Month-to-month
# 78                Mailed check             DSL       0-24        One year
# 80                Mailed check             DSL      25-48  Month-to-month
# 81                Mailed check             DSL      25-48        One year
# 85                Mailed check             DSL      49-72        Two year
# 86                Mailed check     Fiber optic       0-24  Month-to-month
# 88                Mailed check     Fiber optic      25-48  Month-to-month
# 94                Mailed check              No       0-24  Month-to-month
# 95                Mailed check              No       0-24        One year
# 96                Mailed check              No       0-24        Two year
# 98                Mailed check              No      25-48        One year
# 99                Mailed check              No      25-48        Two year
# 102               Mailed check              No      49-72        Two year
#
#      ChurnNum  Count
# 0    0.237288    118
# 3    0.157895     57
# 4    0.056604     53
# 7    0.057971     69
# 8    0.015075    199
# 9    0.594937    158
# 11   0.411765    102
# 12   0.080000     50
# 14   0.194030     67
# 15   0.168317    101
# 16   0.099338    151
# 17   0.230769     52
# 21   0.027027     37
# 22   0.000000     35
# 24   0.007752    129
# 25   0.313559    118
# 28   0.220000     50
# 29   0.103896     77
# 30   0.032258     31
# 32   0.057971     69
# 33   0.020305    197
# 34   0.540146    137
# 36   0.323529    102
# 37   0.171429     35
# 39   0.277778     54
# 40   0.160377    106
# 41   0.041379    145
# 42   0.105263     57
# 47   0.025000     40
# 50   0.007874    127
# 51   0.468665    367
# 54   0.181818     77
# 55   0.043478     46
# 58   0.113636     44
# 59   0.081633     49
# 60   0.676072    886
# 63   0.489510    286
# 64   0.288136     59
# 66   0.370370    135
# 67   0.248062    129
# 68   0.086420     81
# 69   0.232143     56
# 77   0.347962    319
# 78   0.108696     46
# 80   0.046512     43
# 81   0.138462     65
# 85   0.000000     61
# 86   0.568750    160
# 88   0.354839     31
# 94   0.214521    303
# 95   0.019608    102
# 96   0.000000     71
# 98   0.000000     46
# 99   0.013158     76
# 102  0.010000    100

# %%
risky_group.sort_values(by='ChurnNum',ascending=False).head()
# Out:
#                 PaymentMethod InternetService TenureBins        Contract  \
# 60           Electronic check     Fiber optic       0-24  Month-to-month
# 9   Bank transfer (automatic)     Fiber optic       0-24  Month-to-month
# 86               Mailed check     Fiber optic       0-24  Month-to-month
# 34    Credit card (automatic)     Fiber optic       0-24  Month-to-month
# 63           Electronic check     Fiber optic      25-48  Month-to-month
#
#     ChurnNum  Count
# 60  0.676072    886
# 9   0.594937    158
# 86  0.568750    160
# 34  0.540146    137
# 63  0.489510    286

# %%
risky_group.sort_values(by='ChurnNum',ascending=True).head()
# Out:
#                 PaymentMethod InternetService TenureBins  Contract  ChurnNum  \
# 22  Bank transfer (automatic)              No      25-48  Two year  0.000000
# 98               Mailed check              No      25-48  One year  0.000000
# 96               Mailed check              No       0-24  Two year  0.000000
# 85               Mailed check             DSL      49-72  Two year  0.000000
# 24  Bank transfer (automatic)              No      49-72  Two year  0.007752
#
#     Count
# 22     35
# 98     46
# 96     71
# 85     61
# 24    129
